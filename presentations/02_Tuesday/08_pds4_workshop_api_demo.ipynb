# %%
from psa_utils import tap
import pyvo as vo
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import IPython.display as display
from PIL import Image
import pds4_tools
import pdr

t = tap.PsaTap()

# %% [markdown]
# # Intro to EPN-TAP

# %% [markdown]
# TAP uses ADQL, a SQL-like language to run searches. Let's try some basic queries:

# %% [markdown]
# What missions do we have public data in PSA for?

# %%
t.query('SELECT DISTINCT instrument_host_name FROM psa.epn_core')
# Out:
#    instrument_host_name
# 0           BepiColombo
# 1         Chandrayaan-1
# 2          ExoMars 2016
# 3                Giotto
# 4          Ground Based
# 5                Hubble
# 6               Huygens
# 7                 JUICE
# 8          Mars Express
# 9           Peregrine-1
# 10              Rosetta
# 11              SMART-1
# 12        Venus Express

# %% [markdown]
# And how many instruments are supported?

# %%
t.query('SELECT COUNT(DISTINCT instrument_name) FROM epn_core')
# Out:
#    COUNT
# 0    151

# %% [markdown]
# What is the breakdown of products per mission?

# %%
t.query("""
    SELECT instrument_host_name, count(*) as num_prod 
    FROM epn_core 
    GROUP BY instrument_host_name 
    ORDER BY num_prod DESC
    """)
# Out:
#    instrument_host_name  num_prod
# 0          ExoMars 2016  27515795
# 1               Rosetta   8280675
# 2          Mars Express   1697885
# 3         Venus Express    623419
# 4               SMART-1    604527
# 5           BepiColombo    189911
# 6         Chandrayaan-1     20345
# 7               Huygens     13995
# 8                 JUICE      3441
# 9                Giotto      2129
# 10         Ground Based      2083
# 11          Peregrine-1        86
# 12               Hubble        33

# %% [markdown]
# And the breakdown by total archive size?

# %%
t.query("""
    SELECT instrument_host_name, sum(access_estsize)/1024./1024. as prod_size 
    FROM epn_core 
    WHERE access_estsize IS NOT NULL 
    GROUP BY instrument_host_name 
    ORDER BY prod_size DESC
    """)
# Out:
#    instrument_host_name     prod_size
# 0          ExoMars 2016  96541.871964
# 1               Rosetta  80268.986265
# 2          Mars Express  40407.061924
# 3         Venus Express   5152.179532
# 4               SMART-1    434.483055
# 5         Chandrayaan-1    322.819281
# 6          Ground Based     71.464685
# 7           BepiColombo     64.553326
# 8                 JUICE      8.276659
# 9               Huygens      6.176440
# 10               Giotto      0.372127
# 11               Hubble      0.116873
# 12          Peregrine-1      0.005086

# %% [markdown]
# # Drilling into the data

# %% [markdown]
# Which instruments have observed Mars?

# %%
t.query("SELECT DISTINCT instrument_name FROM psa.epn_core WHERE target_name='Mars'")
# Out:
#    instrument_name
# 0              ACS
# 1            ALICE
# 2         ASPERA-3
# 3             CIVA
# 4          CONSERT
# 5            COSAC
# 6           CaSSIS
# 7            FREND
# 8             HRSC
# 9           MARSIS
# 10            MaRS
# 11          NAVCAM
# 12           NOMAD
# 13           OMEGA
# 14          OSIRIS
# 15             PFS
# 16           ROMAP
# 17             RPC
# 18             RSI
# 19          SESAME
# 20          SPICAM
# 21          SPICAV
# 22            SREM
# 23          VIRTIS
# 24             VMC

# %% [markdown]
# Let's look at those NAVCAM data...

# %%
result = t.query("SELECT top 1 * FROM psa.epn_core WHERE target_name='Mars' and instrument_name='NAVCAM'")

# %%
result.T
# Out:
#                                                                       0
# access_estsize                                                     2071
# access_format                                     application/x-pds-zip
# access_url            https://psa.esa.int/psa-tap/data?retrieval_acc...
# c1max                                                        135.795819
# c1min                                                       -124.884818
# c2max                                                         53.574039
# c2min                                                        -52.469715
# creation_date                                   2016-12-28T16:06:37.101
# datalabs_path         /data/psa_psa01_datalabs01/INTERNATIONAL-ROSET...
# dataproduct_type                                                     ci
# granule_gid                            RO-M/CAL-NAVCAM-2-MARS-V1.1:DATA
# granule_uid           RO-M/CAL-NAVCAM-2-MARS-V1.1:DATA:ROS_CAM1_2007...
# instrument_host_name                                            Rosetta
# instrument_name                                                  NAVCAM
# instrument_type
# label_url             https://archives.esac.esa.int/psa/ftp/INTERNAT...
# measurement_type
# modification_date                               2016-12-28T16:06:37.101
# obs_id                RO-M/CAL-NAVCAM-2-MARS-V1.1:DATA:ROS_CAM1_2007...
# processing_level                                                      3
# release_date                                      2017-08-25T00:00:00.0
# s_region
# service_title                                                       psa
# spatial_frame_type                                                 body
# target_class                                                     planet
# target_name                                                        Mars
# thumbnail_url         https://psa.esa.int/psa-tap/data?retrieval_acc...
# time_max                                  2007-02-24 18:05:32.926015553
# time_min                                  2007-02-24 18:05:32.775986195

# %% [markdown]
# The `thumbnail_url` gives the snapshots images of the data

# %%
url = result.thumbnail_url.squeeze()
url
# Out:
# 'https://psa.esa.int/psa-tap/data?retrieval_access=DIRECT&retrieval_type=IMAGE&lidvid=urn:esa:psa:bc_mtm_mcam:data_raw:cam_raw_sc_cam3_image_20260903t024026_08_fi_t0004::1.0'

# %%
display.Image(url=url, width=500, embed=True, format='png')

# %%
url = result.access_url.squeeze()
url
# Out:
# 'https://psa.esa.int/psa-tap/data?retrieval_access=DIRECT&retrieval_type=PRODUCT&tapclient=EPN-TAP&id=RO-M/CAL-NAVCAM-2-MARS-V1.1:DATA:ROS_CAM1_20070224T180532'

# %% [markdown]
# ## Retrieving PDS4 data

# %%
result = t.query("SELECT top 1 * FROM psa.epn_core WHERE instrument_name='MCAM' ORDER BY time_min DESC")

# %%
result
# Out:
#    access_estsize          access_format  \
# 0            2069  application/x-pds-zip
#
#                                           access_url          creation_date  \
# 0  https://psa.esa.int/psa-tap/data?retrieval_acc...  2026-09-03T00:00:00.0
#
#                                        datalabs_path dataproduct_type  \
# 0  /data/psa_psa01_datalabs01/BepiColombo/bc_mtm_...               ci
#
#                         granule_gid  \
# 0  urn:esa:psa:bc_mtm_mcam:data_raw
#
#                                          granule_uid instrument_host_name  \
# 0  urn:esa:psa:bc_mtm_mcam:data_raw:cam_raw_sc_ca...          BepiColombo
#
#   instrument_name  ... processing_level           release_date s_region  \
# 0            MCAM  ...                2  2023-06-22T00:00:00.0
#
#   service_title spatial_frame_type  target_class target_name  \
# 0           psa               none
#
#                                        thumbnail_url  \
# 0  https://psa.esa.int/psa-tap/data?retrieval_acc...
#
#                        time_max                      time_min
# 0 2026-09-03 02:40:26.699987049 2026-09-03 02:40:26.696003975
#
# [1 rows x 25 columns]

# %%
struct = pds4_tools.read(result.label_url.iloc[0])
# Out:
# Processing label: https://archives.esac.esa.int/psa/ftp/BepiColombo/bc_mtm_mcam/data_raw/cruise/202609/cam_raw_sc_cam3_image_20260903t024026_08_fi_t0004__1_0.lblx
# Downloading URL: https://archives.esac.esa.int/psa/ftp/BepiColombo/bc_mtm_mcam/data_raw/cruise/202609/cam_raw_sc_cam3_image_20260903t024026_08_fi_t0004__1_0.lblx ... done
# Now processing a Header structure: FITS primary header
# Downloading URL: https://archives.esac.esa.int/psa/ftp/BepiColombo/bc_mtm_mcam/data_raw/cruise/202609/cam_raw_sc_cam3_image_20260903t024026_08_fi_t0004__1_0.fits ...
# 100% [==================================================] (2.11 / 2.11 MB)
# Now processing a Header structure: FITS extension header
# Now processing a Array_2D_Image structure: MCAM_image

# %%
struct
# Out:
# <StructureList at 0x17ce2c7d0> with:
# <HeaderStructure 'FITS primary header' at 0x17cc55a70>
# <HeaderStructure 'FITS extension header' at 0x17ccdfdf0>
# <ArrayStructure 'MCAM_image' at 0x17ce2c690>

# %%
image = struct['MCAM_image']
image
# Out:
# <ArrayStructure 'MCAM_image' at 0x17ce2c690>

# %%
plt.imshow(image.data, plt.cm.gray)

# %% [markdown]
# # Geometry search in EPN-TAP

# %% [markdown]
# Bounding boxes are also included in EPN-TAP for data proucts providing geometry. We can uses these in queries to geographically limit our search.

# %%
start = pd.Timestamp('2021-07-01').to_julian_date()
end = pd.Timestamp('2021-10-31').to_julian_date()

# %%
start, end
# Out:
# (np.float64(2459396.5), np.float64(2459518.5))

# %%
query = """
    SELECT granule_uid, time_min, time_max, c1min, c1max, c2min, c2max  
    from psa.epn_core where 
    (c1min >= -143 and c1max <= -125 AND c2min >= 11 AND c2max <= 27) and 
    instrument_name = 'CaSSIS' and
    processing_level=3 and
    time_min>{:f} and
    time_max<{:f} 
    order by time_min asc
    """.format(start, end)

# %%
data = t.query(query)

# %%
data.head()
# Out:
#                                          granule_uid  \
# 0  urn:esa:psa:em16_tgo_cas:data_calibrated:cas_c...
# 1  urn:esa:psa:em16_tgo_cas:data_calibrated:cas_c...
# 2  urn:esa:psa:em16_tgo_cas:data_calibrated:cas_c...
#
#                        time_min                      time_max       c1min  \
# 0 2021-08-04 14:20:18.999999764 2021-08-04 14:20:36.999982593 -127.682834
# 1 2021-08-04 14:20:18.999999764 2021-08-04 14:20:36.999982593 -127.676931
# 2 2021-08-04 14:20:18.999999764 2021-08-04 14:20:36.999982593 -127.665120
#
#         c1max      c2min      c2max
# 0 -126.913470  15.605134  15.917998
# 1 -126.907011  15.578415  15.891477
# 2 -126.894043  15.524833  15.838318

# %% [markdown]
# Recall that:
# - c1 = longitude
# - c2 = latitude

# %%
data['width'] = data.c1max-data.c1min
data['height'] = data.c2max-data.c2min
data = data[data.width>0]

# %%
len(data)
# Out:
# 3

# %%
def plot_bounding(data, zoom=True, margin=1.0):
    Image.MAX_IMAGE_PIXELS = None
    max_lat =  -90.
    min_lat =  +90.
    max_lon =    -180.
    min_lon = 180.
    fig, ax= plt.subplots(figsize=(14,9))
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    # img = plt.imread('/Users/mbentley/Downloads/Mars_MGS_MOLA_ClrShade_merge_global_463m.tif')
    img = plt.imread('/Users/mbentley/Downloads/Mars_MGS_MOLA_ClrShade_merge_global_463m_3.tif')
    ax.imshow(img, zorder=0,  extent=[-180, 180, -90.0, 90.0], alpha=1.0, interpolation='None')
    for idx, row in data.iterrows():
        width = row.c1max-row.c1min
        height = row.c2max-row.c2min
        if width < 0.:
            continue
        min_lat = row.c2min if row.c2min < min_lat else min_lat
        max_lat = row.c2max if row.c2max > max_lat else max_lat
        min_lon = row.c1min if row.c1min < min_lon else min_lon
        max_lon = row.c1max if row.c1max > max_lon else max_lon
        ax.add_patch(Rectangle((row.c1min, row.c2min), width, height, fill=None, alpha=1., color='r'))
    if zoom:
        ax.set_xlim(min_lon-margin, max_lon+margin)
        ax.set_ylim(min_lat-margin, max_lat+margin)

# %%
plot_bounding(data, zoom=False)

# %%
plot_bounding(data, zoom=True)

# %% [markdown]
# # Advancecd: using PostGIS functions via TAP

# %% [markdown]
# This is not documented ;-) but it is possible to use postGIS functions to the TAP service and get data back....

# %%
q = t.query("""
    select top 1 ST_AsGeoJSON(footprint_geometry), ST_AsGeoJSON(Box2D(footprint_geometry)) 
    from psa.product_ui where footprint_geometry is not null
    """)

# %%
q.squeeze().iloc[0]
# Out:
# '{"type":"Polygon","coordinates":[[[-18.903273,25.347425],[-18.90132,25.346776],[-18.899368,25.346127],[-18.897416,25.345478],[-18.895463,25.344829],[-18.893511,25.34418],[-18.891558,25.343531],[-18.889606,25.342882],[-18.887654,25.342233],[-18.885701,25.341584],[-18.883749,25.340935],[-18.881797,25.340286],[-18.879844,25.339637],[-18.877892,25.338988],[-18.87594,25.338339],[-18.873988,25.33769],[-18.872035,25.337041],[-18.870083,25.336392],[-18.868131,25.335743],[-18.866179,25.335094],[-18.864227,25.334445],[-18.862274,25.333795],[-18.860322,25.333146],[-18.85837,25.332497],[-18.856418,25.331848],[-18.854466,25.331199],[-18.852514,25.33055],[-18.850562,25.3299],[-18.84861,25.329251],[-18.846658,25.328602],[-18.844706,25.327953],[-18.842754,25.327303],[-18.840802,25.326654],[-18.83885,25.326005],[-18.836898,25.325355],[-18.834946,25.324706],[-18.832994,25.324057],[-18.831042,25.323407],[-18.829091,25.322758],[-18.827139,25.322109],[-18.825187,25.321459],[-18.823235,25.32081],[-18.821283,25.32016],[-18.819331,25.319511],[-18.81738,25.318861],[-18.815428,25.318212],[-18.813476,25.317562],[-18.811524,25.316913],[-18.809573,25.316263],[-18.807621,25.315614],[-18.805669,25.314964],[-18.803717,25.314315],[-18.801766,25.313665],[-18.799814,25.313016],[-18.797862,25.312366],[-18.795911,25.311716],[-18.793959,25.311067],[-18.792008,25.310417],[-18.790056,25.309767],[-18.788104,25.309118],[-18.786153,25.308468],[-18.784201,25.307818],[-18.78225,25.307169],[-18.780298,25.306519],[-18.778347,25.305869],[-18.776395,25.305219],[-18.774444,25.30457],[-18.772492,25.30392],[-18.770541,25.30327],[-18.76859,25.30262],[-18.766638,25.30197],[-18.764687,25.30132],[-18.762735,25.300671],[-18.760784,25.300021],[-18.758833,25.299371],[-18.756881,25.298721],[-18.75493,25.298071],[-18.752979,25.297421],[-18.751027,25.296771],[-18.749076,25.296121],[-18.747125,25.295471],[-18.745173,25.294821],[-18.743222,25.294171],[-18.741271,25.293521],[-18.73932,25.292871],[-18.737368,25.292221],[-18.735417,25.291571],[-18.733466,25.290921],[-18.734144,25.289273],[-18.734822,25.287625],[-18.735499,25.285977],[-18.736177,25.284329],[-18.736855,25.282682],[-18.737532,25.281034],[-18.738209,25.279387],[-18.738887,25.27774],[-18.739564,25.276094],[-18.740241,25.274447],[-18.740918,25.272801],[-18.742272,25.269508],[-18.744221,25.270158],[-18.746171,25.270807],[-18.74812,25.271457],[-18.75007,25.272106],[-18.75202,25.272756],[-18.753969,25.273405],[-18.755919,25.274055],[-18.757869,25.274704],[-18.759818,25.275354],[-18.761768,25.276003],[-18.763718,25.276653],[-18.765667,25.277302],[-18.767617,25.277951],[-18.769567,25.278601],[-18.771517,25.27925],[-18.773467,25.279899],[-18.775416,25.280549],[-18.777366,25.281198],[-18.779316,25.281847],[-18.781266,25.282496],[-18.783216,25.283146],[-18.785165,25.283795],[-18.787115,25.284444],[-18.789065,25.285093],[-18.791015,25.285743],[-18.792965,25.286392],[-18.794915,25.287041],[-18.796865,25.28769],[-18.798815,25.288339],[-18.800765,25.288988],[-18.802715,25.289637],[-18.804665,25.290286],[-18.806615,25.290936],[-18.808565,25.291585],[-18.810515,25.292234],[-18.812465,25.292883],[-18.814415,25.293532],[-18.816365,25.294181],[-18.818315,25.29483],[-18.820265,25.295479],[-18.822215,25.296128],[-18.824165,25.296777],[-18.826116,25.297425],[-18.828066,25.298074],[-18.830016,25.298723],[-18.831966,25.299372],[-18.833916,25.300021],[-18.835867,25.30067],[-18.837817,25.301319],[-18.839767,25.301968],[-18.841717,25.302616],[-18.843668,25.303265],[-18.845618,25.303914],[-18.847568,25.304563],[-18.849519,25.305212],[-18.851469,25.30586],[-18.853419,25.306509],[-18.85537,25.307158],[-18.85732,25.307806],[-18.859271,25.308455],[-18.861221,25.309104],[-18.863171,25.309752],[-18.865122,25.310401],[-18.867072,25.31105],[-18.869023,25.311698],[-18.870973,25.312347],[-18.872924,25.312996],[-18.874874,25.313644],[-18.876825,25.314293],[-18.878776,25.314941],[-18.880726,25.31559],[-18.882677,25.316238],[-18.884627,25.316887],[-18.886578,25.317535] ...

# %% [markdown]
# Example of getting footprints of data

# %%
q="""
    select top 1000 logical_identifier, start_date_time, instrument_name, ST_AsText(footprint_geometry) as footprint_geometry, 
    ST_AsText(footprint_geometry_nosplit) as footprint_geometry_nosplit
    from psa.product_ui_mex where footprint_geometry is not null and 
    target_name='Mars' AND 
    lastproduct='true' AND 
    instrument_name = 'HRSC' AND
    (ST_Contains(ST_GeomFromText('POLYGON((-30 -30, -30 30, 30 30, 30 -30, -30 -30))',949900),ST_SetSRID(footprint_geometry,949900))='true') AND footprint_srid=949900
    order by start_date_time desc
    """
